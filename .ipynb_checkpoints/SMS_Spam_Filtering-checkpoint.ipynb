# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('spam.csv')

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 3949  ham  I got to video tape pple type in message lor. ...        NaN
# 1381  ham  We spend our days waiting for the ideal path t...        NaN
# 4990  ham  We made it! Eta at taunton is 12:30 as planned...        NaN
# 5347  ham  No sir. That's why i had an 8-hr trip on the b...        NaN
# 2881  ham    Hi Harish's rent has been transfred to ur Acnt.        NaN
#
#      Unnamed: 3 Unnamed: 4
# 3949        NaN        NaN
# 1381        NaN        NaN
# 4990        NaN        NaN
# 5347        NaN        NaN
# 2881        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
#Data Cleaning
#EDA
#Text Preprocessing
#Model Building
#Evaluation
#Improvement
#Website
#Deploy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.drop(columns=df.iloc[:,[2,3,4]],inplace=True)

# %%
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.rename(columns={'v1':'Target','v2':'Text'},inplace=True)
df
# Out:
#      Target                                               Text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['Target'] = encoder.fit_transform(df['Target']) #converts ham to 0 and spam to 1

# %%
df
# Out:
#       Target                                               Text
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Target    0
# Text      0
# dtype: int64

# %%
#checking duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ###EDA

# %%
df['Target'].value_counts()
# Out:
# Target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
plt.pie(df['Target'].value_counts(), labels = ['ham','spam'],autopct = '%0.2f')
plt.show()

# %%
#DATA IS IMBALANCED AS SHOWN IN THIS FIGURE ABOVE

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sulav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_char'] = df['Text'].apply(len)
# Out:
# C:\Users\sulav\AppData\Local\Temp\ipykernel_2004\197197665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_char'] = df['Text'].apply(len)

# %%
df.head()
# Out:
#    Target                                               Text  num_char
# 0       0  Go until jurong point, crazy.. Available only ...       111
# 1       0                      Ok lar... Joking wif u oni...        29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3       0  U dun say so early hor... U c already then say...        49
# 4       0  Nah I don't think he goes to usf, he lives aro...        61

# %%
#fetching the number of words
df['num_words'] = df['Text'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# C:\Users\sulav\AppData\Local\Temp\ipykernel_2004\3166703106.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_words'] = df['Text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.sample(5)
# Out:
#       Target                                               Text  num_char  \
# 2088       1  Well done ENGLAND! Get the official poly ringt...       156
# 1878       0                  I AM AT A PARTY WITH ALEX NICHOLS        33
# 845        0  Meanwhile in the shit suite: xavier decided to...       231
# 78         0         Does not operate after  &lt;#&gt;  or what        42
# 4065       0  Fyi I'm gonna call you sporadically starting a...        97
#
#       num_words
# 2088         32
# 1878          8
# 845          52
# 78           13
# 4065         26

# %%
df['num_sentences'] = df['Text'].apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# C:\Users\sulav\AppData\Local\Temp\ipykernel_2004\1884457437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sentences'] = df['Text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       Target                                               Text  num_char  \
# 0          0  Go until jurong point, crazy.. Available only ...       111
# 1          0                      Ok lar... Joking wif u oni...        29
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3          0  U dun say so early hor... U c already then say...        49
# 4          0  Nah I don't think he goes to usf, he lives aro...        61
# ...      ...                                                ...       ...
# 5567       1  This is the 2nd time we have tried 2 contact u...       161
# 5568       0              Will Ì_ b going to esplanade fr home?        37
# 5569       0  Pity, * was in mood for that. So...any other s...        57
# 5570       0  The guy did some bitching but I acted like i'd...       125
# 5571       0                         Rofl. Its true to its name        26
#
#       num_words  num_sentences
# 0            24              2
# 1             8              2
# 2            37              2
# 3            13              1
# 4            15              1
# ...         ...            ...
# 5567         35              4
# 5568          9              1
# 5569         15              2
# 5570         27              1
# 5571          7              2
#
# [5169 rows x 5 columns]

# %%
df.describe()
# Out:
#             Target     num_char    num_words  num_sentences
# count  5169.000000  5169.000000  5169.000000    5169.000000
# mean      0.126330    78.977945    18.455794       1.965564
# std       0.332253    58.236293    13.324758       1.448541
# min       0.000000     2.000000     1.000000       1.000000
# 25%       0.000000    36.000000     9.000000       1.000000
# 50%       0.000000    60.000000    15.000000       1.000000
# 75%       0.000000   117.000000    26.000000       2.000000
# max       1.000000   910.000000   220.000000      38.000000

# %%
# on average 78 characters are used, roughly 2 sentences are used and  max 220 wwords are used with 38 sentences

# %% [markdown]
# ###ham

# %%
df[df['Target'] == 0] [['num_char','num_words','num_sentences']].describe()
# Out:
#           num_char    num_words  num_sentences
# count  4516.000000  4516.000000    4516.000000
# mean     70.459256    17.123782       1.820195
# std      56.358207    13.493970       1.383657
# min       2.000000     1.000000       1.000000
# 25%      34.000000     8.000000       1.000000
# 50%      52.000000    13.000000       1.000000
# 75%      90.000000    22.000000       2.000000
# max     910.000000   220.000000      38.000000

# %% [markdown]
# ###Spam

# %%
df[df['Target'] == 1] [['num_char','num_words','num_sentences']].describe()
# Out:
#          num_char   num_words  num_sentences
# count  653.000000  653.000000     653.000000
# mean   137.891271   27.667688       2.970904
# std     30.137753    7.008418       1.488425
# min     13.000000    2.000000       1.000000
# 25%    132.000000   25.000000       2.000000
# 50%    149.000000   29.000000       3.000000
# 75%    157.000000   32.000000       4.000000
# max    224.000000   46.000000       9.000000

# %%
#137.891271 spam per messages this can show that spam message is lengthier or larger than the ham

# %%
#Character_based
plt.figure(figsize=(14,10))
sns.histplot(df[df['Target']==0]['num_char'], color ='blue')
sns.histplot(df[df['Target']==1]['num_char'],color = 'red')
# Out:
# <Axes: xlabel='num_char', ylabel='Count'>

# %%
#maximum ham average characters are lesser than the max spam characters clearly visible

# %%
#word_based
plt.figure(figsize=(14,10))
sns.histplot(df[df['Target']==0]['num_words'], color ='blue')
sns.histplot(df[df['Target']==1]['num_words'],color = 'red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df, hue='Target')

# %%
#Outliers are present that can affect analysis

# %%
correlation_matrix = df[['Target', 'num_char', 'num_words', 'num_sentences']].corr()

# %%
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
#for making a model you need to use num_words as it has the highest collinearity

# %% [markdown]
# ###Data or Text Preprocessing

# %%
#-lower case
#-Tokenization
#-Removing Special Characters
#-Removing stop words and punctuation
#-Stemming(converting the words with similar meaning as one.eg dancing dances danced into dance )

# %%
from nltk.corpus import stopwords
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ###Porter Stemmer for stemming

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('dancing')
# Out:
# 'danc'

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)

    y=[]
    for i in text:
        if i.isalnum():#alphanumeric
            y.append(i)
            
    text = y[:]
    y.clear()

    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)

    text = y[:]
    y.clear()

    for i in text:
        y.append(ps.stem(i))

    return " ".join(y)

# %%
#from nltk.corpus import stopwords
#stopwords.words('english')
#e removes as it is basics of nltk but word mean it danc means dance

# %%
transform_text("I am trying to learn Machine Learning from youtube watching the lectures. How about you? ")
# Out:
# 'tri learn machin learn youtub watch lectur'

# %%
df['Text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
df['Transformed_text']=df['Text'].apply(transform_text)
# Out:
# C:\Users\sulav\AppData\Local\Temp\ipykernel_2004\1687500628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Transformed_text']=df['Text'].apply(transform_text)

# %%
df.head()
# Out:
#    Target                                               Text  num_char  \
# 0       0  Go until jurong point, crazy.. Available only ...       111
# 1       0                      Ok lar... Joking wif u oni...        29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...       155
# 3       0  U dun say so early hor... U c already then say...        49
# 4       0  Nah I don't think he goes to usf, he lives aro...        61
#
#    num_words  num_sentences                                   Transformed_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                              ok lar joke wif u oni
# 2         37              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         13              1                u dun say earli hor u c alreadi say
# 4         15              1               nah think goe usf live around though

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500, height = 500, min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['Target']==1]['Transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(14,10))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['Target']==0]['Transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(14,10))
plt.imshow(ham_wc)

# %%
spam_msg=[]
for msg in df[df['Target']==1]['Transformed_text'].tolist():
    for word in msg.split():
        spam_msg.append(word)

# %%
len(spam_msg)
# Out:
# 9939

# %%
from collections import Counter
pd.DataFrame(Counter(spam_msg).most_common(30))
# Out:
#           0    1
# 0      call  320
# 1      free  191
# 2         2  155
# 3       txt  141
# 4      text  122
# 5         u  119
# 6        ur  119
# 7     mobil  114
# 8      stop  104
# 9     repli  103
# 10    claim   98
# 11        4   97
# 12    prize   82
# 13      get   74
# 14      new   64
# 15   servic   64
# 16     tone   63
# 17     send   60
# 18   urgent   57
# 19    nokia   57
# 20  contact   56
# 21    award   55
# 22    phone   52
# 23     cash   51
# 24    pleas   51
# 25     week   49
# 26      win   48
# 27        c   45
# 28  collect   45
# 29      min   45

# %%
ham_msg=[]
for msg in df[df['Target']==0]['Transformed_text'].tolist():
    for word in msg.split():
        ham_msg.append(word)

# %%
len(ham_msg)
# Out:
# 35404

# %%
from collections import Counter
pd.DataFrame(Counter(ham_msg).most_common(30))
# Out:
#         0    1
# 0       u  883
# 1      go  404
# 2     get  349
# 3      gt  288
# 4      lt  287
# 5       2  284
# 6    come  275
# 7     got  236
# 8    know  236
# 9    like  234
# 10   call  233
# 11   time  219
# 12     ok  217
# 13   love  216
# 14   good  213
# 15   want  208
# 16     ur  197
# 17    day  190
# 18   need  170
# 19    one  165
# 20    lor  159
# 21      4  156
# 22   home  152
# 23  think  149
# 24    see  147
# 25   take  143
# 26  still  143
# 27     da  142
# 28   tell  133
# 29   make  129

# %% [markdown]
# ###MODEL BUILDING

# %%
#naive bayes has the most efficient results on terms of the textual data

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
#X = cv.fit_transform(df['Transformed_text']).toarray()

# %%
X = tfidf.fit_transform(df['Transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['Target'].values

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import  GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %% [markdown]
# ###Naive bayes best for text so fitting with its variants

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print("Accuracy Score: ", accuracy_score(y_test,y_pred1))
print("Confusion matrix: ", confusion_matrix(y_test,y_pred1))
print("precision score: ", precision_score(y_test,y_pred1))
#bad performance with precision score and imbalanced dataset require more precision score
# Out:
# Accuracy Score:  0.8694390715667312
# Confusion matrix:  [[788 108]
#  [ 27 111]]
# precision score:  0.5068493150684932

# %%
bnb.fit(X_train,y_train)
y_pred2 = bnb.predict(X_test)
print("Accuracy Score: ", accuracy_score(y_test,y_pred2))
print("Confusion matrix: ", confusion_matrix(y_test,y_pred2))
print("precision score: ", precision_score(y_test,y_pred2))
# Out:
# Accuracy Score:  0.9835589941972921
# Confusion matrix:  [[895   1]
#  [ 16 122]]
# precision score:  0.991869918699187

# %%
model=mnb.fit(X_train,y_train)
y_pred3 = mnb.predict(X_test)
print("Accuracy Score: ", accuracy_score(y_test,y_pred3))
print("Confusion matrix: ", confusion_matrix(y_test,y_pred3))
print("precision score: ", precision_score(y_test,y_pred3))
# Out:
# Accuracy Score:  0.9709864603481625
# Confusion matrix:  [[896   0]
#  [ 30 108]]
# precision score:  1.0

# %%
input_text = "hello you have been rewarded with a prize worth 10000 call for reward"
input_text = tfidf.transform([input_text])

# Make a prediction
prediction = model.predict(input_text)

# Check the prediction
if prediction[0] == 1:
    print("This is a spam message.")
else:
    print("This is a ham (non-spam) message.")
# Out:
# This is a spam message.

# %%
# tdidf --> MNB best with precision score as data is imbalanced accuracy score is not reliable much.

# %%
# import pickle
# pickle.dump(tfidf,open('vectorizer.pkl','wb'))
# pickle.dump(mnb,open('model.pkl','wb'))
